# %%
import numpy as np 
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas 
import numpy as np 
 
# supress scientific notation 
np.set_printoptions(suppress = True) 
 
# read the data file from GitHub and convert to a NumPy ndarray object 
# be sure to replace the ‘link_to_raw_copy of data file in your Github Repository’ placeholder shown below 
# with a link to the “raw” version of the file you pushed to your online GitHub repository 
 
nyc_water = pandas.read_csv(link_to_raw_copy of data file in your Github Repository).to_numpy() 
 
# verify you have an ndarray object 
type(nyc_water)
# Out:
#   File "/var/folders/9x/73zqfl0117l97h4kz7x8mgs80000gn/T/ipykernel_37580/4265655290.py", line 11
#     nyc_water = pandas.read_csv(‘link_to_raw_copy of data file in your Github Repository').to_numpy()
#                                 ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
df
# Out:
# array([[1.9790000e+03, 7.1021000e+06, 1.5120000e+03, 2.1300000e+02],
#        [1.9800000e+03, 7.0716390e+06, 1.5060000e+03, 2.1300000e+02],
#        [1.9810000e+03, 7.0892410e+06, 1.3090000e+03, 1.8500000e+02],
#        [1.9820000e+03, 7.1091050e+06, 1.3820000e+03, 1.9400000e+02],
#        [1.9830000e+03, 7.1812240e+06, 1.4240000e+03, 1.9800000e+02],
#        [1.9840000e+03, 7.2345140e+06, 1.4650000e+03, 2.0300000e+02],
#        [1.9850000e+03, 7.2740540e+06, 1.3260000e+03, 1.8200000e+02],
#        [1.9860000e+03, 7.3192460e+06, 1.3510000e+03, 1.8500000e+02],
#        [1.9870000e+03, 7.3424760e+06, 1.4470000e+03, 1.9700000e+02],
#        [1.9880000e+03, 7.3537190e+06, 1.4840000e+03, 2.0200000e+02],
#        [1.9890000e+03, 7.3441750e+06, 1.4020000e+03, 1.9100000e+02],
#        [1.9900000e+03, 7.3356500e+06, 1.4240000e+03, 1.9400000e+02],
#        [1.9910000e+03, 7.3745010e+06, 1.4690000e+03, 1.9900000e+02],
#        [1.9920000e+03, 7.4289440e+06, 1.3690000e+03, 1.8400000e+02],
# ...

# %%
#Printing the data frame 
df.head()
# Out:
#    Year  New York City Population  NYC Consumption(Million gallons per day)  \
# 0  1979                 7102100.0                                    1512.0
# 1  1980                 7071639.0                                    1506.0
# 2  1981                 7089241.0                                    1309.0
# 3  1982                 7109105.0                                    1382.0
# 4  1983                 7181224.0                                    1424.0
#
#    Per Capita(Gallons per person per day)
# 0                                     213
# 1                                     213
# 2                                     185
# 3                                     194
# 4                                     198

# %%
#Assigning each column to a numpy array 
x_year_arr = np.array(df['Year'])
x_pop_arr = np.array(df['New York City Population'])
x_Con_arr = np.array(df['NYC Consumption(Million gallons per day)'])
x_PerCap_arr = np.array(df['Per Capita(Gallons per person per day)'])

# %%
total_annual_water_consumption = np.array(x_Con_arr*365)

# %%
master_array = np.append(master_array,total_annual_water_consumption)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9x/73zqfl0117l97h4kz7x8mgs80000gn/T/ipykernel_37580/3366604206.py in <module>
# ----> 1 master_array = np.append(master_array,total_annual_water_consumption)
#
# NameError: name 'master_array' is not defined

# %%
master_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9x/73zqfl0117l97h4kz7x8mgs80000gn/T/ipykernel_37580/2270302803.py in <module>
# ----> 1 master_array
#
# NameError: name 'master_array' is not defined

# %%
np.median(x_Con_arr)
# Out:
# 1237.2

# %%
np.var(x_Con_arr)
# Out:
# 29744.87353057199

# %%
x_indec_water=[]
x_indec_water.append(0)

# %%
for i in range(1,len(total_annual_water_consumption)):
        x_indec_water.append((total_annual_water_consumption[i]-total_annual_water_consumption[i-1]))

# %%
x_indec_water=np.array(x_indec_water)

# %%
x_indec_water
# Out:
# array([0])

# %%
type_nyc = []

# %%
l=np.append(x_Con_arr,x_PerCap_arr)

# %%
l=np.append(x_pop_arr,x_year_arr)

# %%
l=np.append(l,total_annual_water_consumption)

# %%
l
# Out:
# array([7.1021000e+06, 7.0716390e+06, 7.0892410e+06, 7.1091050e+06,
#        7.1812240e+06, 7.2345140e+06, 7.2740540e+06, 7.3192460e+06,
#        7.3424760e+06, 7.3537190e+06, 7.3441750e+06, 7.3356500e+06,
#        7.3745010e+06, 7.4289440e+06, 7.5061660e+06, 7.5704580e+06,
#        7.6330400e+06, 7.6978120e+06, 7.7734430e+06, 7.8582590e+06,
#        7.9476600e+06, 8.0082780e+06, 8.0249635e+06, 8.0416490e+06,
#        8.0583345e+06, 8.0750200e+06, 8.0917055e+06, 8.1083910e+06,
#        8.1250765e+06, 8.1417620e+06, 8.1584475e+06, 8.1751330e+06,
#        8.2840980e+06, 8.3611790e+06, 8.4224600e+06, 8.4719900e+06,
#        8.5165020e+06, 8.5376730e+06, 8.6226980e+06, 1.9790000e+03,
#        1.9800000e+03, 1.9810000e+03, 1.9820000e+03, 1.9830000e+03,
#        1.9840000e+03, 1.9850000e+03, 1.9860000e+03, 1.9870000e+03,
#        1.9880000e+03, 1.9890000e+03, 1.9900000e+03, 1.9910000e+03,
#        1.9920000e+03, 1.9930000e+03, 1.9940000e+03, 1.9950000e+03,
# ...

# %%
np.array(l)
# Out:
# array([[1.5120000e+03, 1.5060000e+03, 1.3090000e+03, 1.3820000e+03,
#         1.4240000e+03, 1.4650000e+03, 1.3260000e+03, 1.3510000e+03,
#         1.4470000e+03, 1.4840000e+03, 1.4020000e+03, 1.4240000e+03,
#         1.4690000e+03, 1.3690000e+03, 1.3685000e+03, 1.3577000e+03,
#         1.3257000e+03, 1.2979000e+03, 1.2055000e+03, 1.2195000e+03,
#         1.2372000e+03, 1.2404000e+03, 1.1840000e+03, 1.1356000e+03,
#         1.0937000e+03, 1.0995000e+03, 1.1380000e+03, 1.0690000e+03,
#         1.1140000e+03, 1.0980000e+03, 1.0075000e+03, 1.0390000e+03,
#         1.0210000e+03, 1.0091000e+03, 1.0061000e+03, 9.9600000e+02,
#         1.0090000e+03, 1.0020000e+03, 9.9020000e+02],
#        [2.1300000e+02, 2.1300000e+02, 1.8500000e+02, 1.9400000e+02,
#         1.9800000e+02, 2.0300000e+02, 1.8200000e+02, 1.8500000e+02,
#         1.9700000e+02, 2.0200000e+02, 1.9100000e+02, 1.9400000e+02,
#         1.9900000e+02, 1.8400000e+02, 1.8200000e+02, 1.7900000e+02,
# ...

# %%
# Out:
# array([[1.5120000e+03, 1.5060000e+03, 1.3090000e+03, 1.3820000e+03,
#         1.4240000e+03, 1.4650000e+03, 1.3260000e+03, 1.3510000e+03,
#         1.4470000e+03, 1.4840000e+03, 1.4020000e+03, 1.4240000e+03,
#         1.4690000e+03, 1.3690000e+03, 1.3685000e+03, 1.3577000e+03,
#         1.3257000e+03, 1.2979000e+03, 1.2055000e+03, 1.2195000e+03,
#         1.2372000e+03, 1.2404000e+03, 1.1840000e+03, 1.1356000e+03,
#         1.0937000e+03, 1.0995000e+03, 1.1380000e+03, 1.0690000e+03,
#         1.1140000e+03, 1.0980000e+03, 1.0075000e+03, 1.0390000e+03,
#         1.0210000e+03, 1.0091000e+03, 1.0061000e+03, 9.9600000e+02,
#         1.0090000e+03, 1.0020000e+03, 9.9020000e+02],
#        [2.1300000e+02, 2.1300000e+02, 1.8500000e+02, 1.9400000e+02,
#         1.9800000e+02, 2.0300000e+02, 1.8200000e+02, 1.8500000e+02,
#         1.9700000e+02, 2.0200000e+02, 1.9100000e+02, 1.9400000e+02,
#         1.9900000e+02, 1.8400000e+02, 1.8200000e+02, 1.7900000e+02,
# ...

# %%
#Creating type nyc ndarray
type_nyc=type_nyc.append(x_year_arr)

# %%
type_nyc.shape

# %%
type_nyc=np.append(type_nyc,x_Con_arr)
